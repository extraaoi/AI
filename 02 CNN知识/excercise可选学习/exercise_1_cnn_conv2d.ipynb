# %% [markdown]
# ## 作业：对图像进行边缘提取。
# ### 包括你的实验结果的结果分析，对结果的预期和实际结果的分析，可能的原因，改进的措施。

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
img = Image.open('bagua.jpg')
plt.imshow(img)

# %% [markdown]
# ### 提示： 观察上图，图像主要有黑白两色构成，还有一些灰度色彩，提取边缘的作业，需要我们考虑课程练习中学习到的卷积，卷积核设定为[1,-1]的例子。
# ### 尝试一下，效果如何？为什么？有哪些改进呢？
# ### 1. 尝试对图片进行预处理为二值图像
# ### 2.使用3x3的2D卷积算子。比如下面的w
# ### 3.考虑到图片是三通道的，你还可以使用3D的卷积算子来处理。repeat函数可以帮你实现。思考思考吧

# %%
w = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])
w
# Out:
# array([[-1, -1, -1],
#        [-1,  8, -1],
#        [-1, -1, -1]])

# %% [markdown]
# #### 上面的w是2D的，我们还可以生成的3D的。

# %%
w1 = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])
w1 = np.repeat(w,3,axis=1)
w1 = w1.reshape([1,3,3,3])
w1.shape
# Out:
# (1, 3, 3, 3)

# %%
w1[0][:,:,1]
# Out:
# array([[-1, -1, -1],
#        [-1,  8, -1],
#        [-1, -1, -1]])

# %% [markdown]
# ### 下面可以j记录一下你对对结果的分析，思考和感悟
